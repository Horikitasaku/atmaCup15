# %% [markdown]
# 評価の点数は整数でしかありませんので
#
# ある程度の小数の省略は効果があるのではないかと思います。

# %%
score = pd.DataFrame({
    "score": pred
})
score['score'] = score['score'].apply(lambda x: np.clip(x, 1, 10))
score.round(2).to_csv("submission_round.csv", index=False) # 小数を省略します

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RMSEは0.007下がりました
